# %% [markdown]
# # This is my Tile
# ## Subtitle

# %%
import numpy
import matplotlib.pyplot as plt
import skimage.data

# %%
values = [20,60,80,40]
plt.pie(values)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
